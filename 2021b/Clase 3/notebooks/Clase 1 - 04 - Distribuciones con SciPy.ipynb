# %% [markdown]
# # Muestreo aleatorio con SciPy

# %% [markdown]
# Plan:
# - Muestreos aleatorios con distintas distribuciones utilizando SciPy.
# - Diseño de experimentos. Ejemplos.

# %%
#import matplotlib.pyplot as plt
# Usaremos Seaborn para visualizar las distribuciones (también podemos hacerlo con Matplotlib)
import seaborn as sns; sns.set(rc={'figure.figsize':(22,4)})

# %%
N_SAMPLES = 10000

# %% [markdown]
# ### Distribución uniforme

# %%
from scipy.stats import uniform

start = 10
width = 20

# RVS = Random Variable Sampling
data_uniform = uniform.rvs(size=N_SAMPLES, loc = start, scale=width)

# %%
type(data_uniform), data_uniform.ndim, data_uniform.shape
# Out:
# (numpy.ndarray, 1, (10000,))

# %%
ax = sns.histplot(data_uniform,
                  bins=100,
                  kde=True )
ax.set(xlabel='Distribución Uniforme', ylabel='Frecuencia')
# Out:
# [Text(0.5, 0, 'Distribución Uniforme'), Text(0, 0.5, 'Frecuencia')]

# %% [markdown]
# ### Distribución normal

# %%
from scipy.stats import norm

mean = 0
std_dev = 1

data_norm = norm.rvs(size=N_SAMPLES,loc=mean,scale=std_dev)

# %%
ax = sns.histplot(data_norm,
                  bins=100,
                  kde=True )
ax.set(xlabel='Distribución Normal', ylabel='Frecuencia')
# Out:
# [Text(0.5, 0, 'Distribución Normal'), Text(0, 0.5, 'Frecuencia')]

# %% [markdown]
# ### Distribución gamma

# %%
from scipy.stats import gamma

a = 5
data_gamma = gamma.rvs(a=5, size=N_SAMPLES)

# %%
ax = sns.histplot(data_gamma,
                  bins=100,
                  kde=True )
ax.set(xlabel='Distribución Gamma', ylabel='Frecuencia')
# Out:
# [Text(0.5, 0, 'Distribución Gamma'), Text(0, 0.5, 'Frecuencia')]

# %% [markdown]
# ### Distribución exponencial

# %%
from scipy.stats import expon

lambda_param = 1

data_expon = expon.rvs(scale=1/lambda_param,loc=0,size=N_SAMPLES)

# %%
ax = sns.histplot(data_expon,
                  bins=100,
                  kde=True )
ax.set(xlabel='Distribución Exponencial', ylabel='Frecuencia')
# Out:
# [Text(0.5, 0, 'Distribución Exponencial'), Text(0, 0.5, 'Frecuencia')]

# %% [markdown]
# ### Distribución de Poisson

# %%
from scipy.stats import poisson
import numpy as np
mean= 3

data_poisson = poisson.rvs(mu=3, size=N_SAMPLES)

# %%
ax = sns.barplot(x=data_poisson,y=np.bincount(data_poisson))
ax.set(xlabel='Distribución de Poisson', ylabel='Frecuencia')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-401f7f19cedd> in <module>
# ----> 1 ax = sns.barplot(x=data_poisson,y=np.bincount(data_poisson))
#       2 ax.set(xlabel='Distribución de Poisson', ylabel='Frecuencia')
#
# D:\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# D:\anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3180                           estimator, ci, n_boot, units, seed,
#    3181                           orient, color, palette, saturation,
# -> 3182                           errcolor, errwidth, capsize, dodge)
#    3183
#    3184     if ax is None:
#
# D:\anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1583         """Initialize the plotter."""
#    1584         self.establish_variables(x, y, hue, data, orient,
# -> 1585                                  order, hue_order, units)
#    1586         self.establish_colors(color, palette, saturation)
#    1587         self.estimate_statistic(estimator, ci, n_boot, seed)
#
# D:\anaconda3\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     205                 # Group the numeric data
#     206                 plot_data, value_label = self._group_longform(vals, groups,
# --> 207                                                               group_names)
#     208
#     209                 # Now handle the hue levels for nested ordering
#
# D:\anaconda3\lib\site-packages\seaborn\categorical.py in _group_longform(self, vals, grouper, order)
#     251
#     252         # Group the val data
# --> 253         grouped_vals = vals.groupby(grouper)
#     254         out_data = []
#     255         for g in order:
#
# D:\anaconda3\lib\site-packages\pandas\core\series.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    1728             squeeze=squeeze,
#    1729             observed=observed,
# -> 1730             dropna=dropna,
#    1731         )
#    1732
#
# D:\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     566                 observed=observed,
#     567                 mutated=self.mutated,
# --> 568                 dropna=self.dropna,
#     569             )
#     570
#
# D:\anaconda3\lib\site-packages\pandas\core\groupby\grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     837                 dropna=dropna,
#     838             )
# --> 839             if not isinstance(gpr, Grouping)
#     840             else gpr
#     841         )
#
# D:\anaconda3\lib\site-packages\pandas\core\groupby\grouper.py in __init__(self, index, grouper, obj, name, level, sort, observed, in_axis, dropna)
#     451         self.name = name
#     452         self.level = level
# --> 453         self.grouper = _convert_grouper(index, grouper)
#     454         self.all_grouper = None
#     455         self.index = index
#
# D:\anaconda3\lib\site-packages\pandas\core\groupby\grouper.py in _convert_grouper(axis, grouper)
#     869     elif isinstance(grouper, (list, Series, Index, np.ndarray)):
#     870         if len(grouper) != len(axis):
# --> 871             raise ValueError("Grouper and axis must be same length")
#     872         return grouper
#     873     else:
#
# ValueError: Grouper and axis must be same length

# %% [markdown]
# ### Distribución binomial

# %%
from scipy.stats import binom

data_binom = binom.rvs(n=10,p=0.8,size=N_SAMPLES)

# %%
ax = sns.distplot( data_binom, kde=False )
ax.set(xlabel='Distribución Binomial', ylabel='Frecuencia')
# Out:
# D:\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 0, 'Distribución Binomial'), Text(0, 0.5, 'Frecuencia')]

# %% [markdown]
# ### Distribución de Bernoulli

# %%
from scipy.stats import bernoulli

data_bernoulli = bernoulli.rvs(size=N_SAMPLES,p=0.6)

# %%
ax= sns.distplot(data_bernoulli, kde=False)
ax.set(xlabel='Bernoulli Distribution', ylabel='Frequency')
# Out:
# [Text(0.5, 0, 'Bernoulli Distribution'), Text(0, 0.5, 'Frequency')]

# %% [markdown]
# # Referencias
